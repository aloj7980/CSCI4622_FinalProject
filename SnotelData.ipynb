# %%
#%requirments
import csv
import dateutil
import numpy as np
import pandas as pd
import random

# %%
# raw csv read into pandas
df = pd.read_csv("snotel_swe_data.csv")
df
# Out:
#                date  snow_water_equivalent  station_id
# 0        2013-01-01                   86.4        1214
# 1        2013-01-02                   86.4        1214
# 2        2013-01-03                   86.4        1214
# 3        2013-01-04                   86.4        1214
# 4        2013-01-05                   86.4        1214
# ...             ...                    ...         ...
# 3056472  2022-12-27                  114.3         670
# 3056473  2022-12-28                  116.8         670
# 3056474  2022-12-29                  116.8         670
# 3056475  2022-12-30                  116.8         670
# 3056476  2022-12-31                  119.4         670
#
# [3056477 rows x 3 columns]

# %%
# # this was an attempt at cleaning 'NA' values
# for station in df_dict.keys():
#     df = df_dict[station]
#     #for v in df['snow_water_equivalent'].values:
#         #if it contains 'NA' values...
#         #print(v)
#     break

# %%
# make a dictionary of our stations individual dataframes
stations = {station: df[df['station_id'] == station] for station in df.station_id.unique()}
print(f'Found {len(stations)} distinct stations.')
# Out:
# Found 837 distinct stations.

# %%
# split each of those into years
for s in stations:
    df = stations[s]
    df['date']= pd.to_datetime(df['date'],format='%Y-%m-%d')
    stations[s] = {year: df[df['date'].dt.year == year] for year in range(2013, 2023)}
# Out:
# /tmp/ipykernel_233602/3041403388.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['date']= pd.to_datetime(df['date'],format='%Y-%m-%d')
# /tmp/ipykernel_233602/3041403388.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['date']= pd.to_datetime(df['date'],format='%Y-%m-%d')
# /tmp/ipykernel_233602/3041403388.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
# `stations` contents look like: {station: {years: {dfs}}

# Let's look at station 1214
stations[1214][2013]
# Out:
#           date  snow_water_equivalent  station_id
# 0   2013-01-01                   86.4        1214
# 1   2013-01-02                   86.4        1214
# 2   2013-01-03                   86.4        1214
# 3   2013-01-04                   86.4        1214
# 4   2013-01-05                   86.4        1214
# ..         ...                    ...         ...
# 360 2013-12-27                   78.7        1214
# 361 2013-12-28                   78.7        1214
# 362 2013-12-29                   78.7        1214
# 363 2013-12-30                   78.7        1214
# 364 2013-12-31                   78.7        1214
#
# [365 rows x 3 columns]

# %%
# get the mean for station 1214 in 2013
stations[1214][2013]['snow_water_equivalent'].mean()
# Out:
# 43.55753424657534
